# %% [markdown]
# We have two classes in RL and they are:
#
# Agent Class: Agent is a piece of code that implements some policy
#
# Environment Class: Enivronment provides observations and rewards to agent.
#
# Environment Class handles actions received from the agents using action method which gives random reward from the number of steps left.

# %%
import random
from typing import List

class SampleEnvironment:
    def __init__(self):
        self.steps_left = 30

    def get_observation(self) -> List[float]:
        return [0.0, 0.0, 0.0]

    def get_actions(self) -> List[int]:
        return [0, 1]

    def is_done(self) -> bool:
        return self.steps_left == 0

    def action(self, action: int) -> float:
        if self.is_done():
            raise Exception("Game Over")
        self.steps_left -= 1
        return random.random()

# %%
class Agent:
    def __init__(self):
        self.total_reward = 0.0

    def step(self, env: SampleEnvironment):
        current_obs = env.get_observation()
        print("Observation {}".format(current_obs))
        actions = env.get_actions()
        print(actions)
        reward = env.action(random.choice(actions))
        self.total_reward += reward
        # print("Total Reward {}".format(self.total_reward))

# %%
if __name__ == "__main__":
    env = SampleEnvironment()
    agent = Agent()
    i=0

    while not env.is_done():
        i=i+1
        print("Steps {}".format(i))
        agent.step(env)

    print("Final Reward: %.4f" % agent.total_reward)
# Out:
# Steps 1
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Steps 2
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Steps 3
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Steps 4
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Steps 5
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Steps 6
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Steps 7
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Steps 8
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Steps 9
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Steps 10
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Steps 11
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Steps 12
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Steps 13
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Steps 14
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Steps 15
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Steps 16
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Steps 17
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Steps 18
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Steps 19
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Steps 20
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# ...
